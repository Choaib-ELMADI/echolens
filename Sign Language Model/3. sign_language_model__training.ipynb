# %% [markdown]
# # **0. Installation:**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 9.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %% [markdown]
# # **1. Test Detection:**

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.5 source="https://imgd.aeplcdn.com/1280x720/n/cw/ec/154203/ford-aspire-car-roof14.jpeg"

# %% [markdown]
# # **2. Test Training 01:**

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=../content/drive/MyDrive/Datasets/Sign_Language/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 111MB/s]
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **3. Test Training 02:**

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=../content/drive/MyDrive/Datasets/Sign_Language/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 81.3MB/s]
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (AMD EPYC 7B12)
# ...

# %% [markdown]
# # **4. Test Training 03:**

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=../content/drive/MyDrive/Datasets/Sign_Language/data.yaml epochs=200 imgsz=640 patience=0
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 23.7MB/s]
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **5. Download Generated Files:**

# %%
import shutil
from google.colab import files

folder_path = "/content/runs/detect/train"
zip_filename = "train.zip"

shutil.make_archive(zip_filename.split(".")[0], "zip", folder_path)
shutil.move(zip_filename, "/content/runs/detect/" + zip_filename)

files.download("/content/runs/detect/" + zip_filename)
